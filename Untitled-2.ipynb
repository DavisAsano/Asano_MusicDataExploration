# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
import glob
from tkinter import *

# %% [markdown]
# First exploration -
# 1) filter release_date to only the first 4 characters (year) store as year_released
# 2) filter year_released to popularity > 80
# 2) Find average danceability for each year ex: if release_date == 1990 > mean()
# 3) plot x = year y = avg danceability

# %%
path = r'C:\Users\dasan\Desktop\Repo\Project' #Read multiple CSV by pattern matching
all_files = glob.glob(path +"/*.csv")
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
len(df) #Length and types of data in CSV
df.dtypes
# Out:
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit              int64
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# dtype: object

# %%
# x= release date y = average----
df.release_date
# Out:
# 0         1922-02-22
# 1         1922-06-01
# 2         1922-03-21
# 3         1922-03-21
# 4               1922
#              ...
# 586667    2020-09-26
# 586668    2020-10-21
# 586669    2020-09-02
# 586670    2021-03-05
# 586671    2015-07-01
# Name: release_date, Length: 586672, dtype: object

# %%
#Year
df["Year Released"] = pd.to_datetime(df['release_date'])
df["Year Released"] = df["Year Released"].dt.year
df
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# 0                6       126903         0                          ['Uli']
# 1                0        98200         0              ['Fernando Pessoa']
# 2                0       181640         0              ['Ignacio Corsini']
# 3                0       176907         0              ['Ignacio Corsini']
# 4                0       163080         0                  ['Dick Haymes']
# ...            ...          ...       ...                              ...
# 586667          50       258267         0                      ['阿YueYue']
# 586668          72       153293         0                   ['ROLE MODEL']
# 586669          70       187601         0                      ['FINNEAS']
# 586670          58       142003         0  ['Gentle Bones', 'Clara Benin']
# 586671          38       214360         0                    ['Afrosound']
#
#                                                id_artists release_date  \
# 0                              ['45tIt06XoI0Iio4LBEVpls']   1922-02-22
# 1                              ['14jtPCOoNZwquk5wd9DxrY']   1922-06-01
# 2                              ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 3                              ['5LiOoJbxVSAMkBS2fUm3X2']   1922-03-21
# 4                              ['3BiJGZsyX9sJchTqcSA7Su']         1922
# ...                                                   ...          ...
# 586667                         ['1QLBXKM5GCpyQQSVMNZqrZ']   2020-09-26
# 586668                         ['1dy5WNgIKQU6ezkpZs4y8z']   2020-10-21
# 586669                         ['37M5pPGs6V1fchFJSgCguX']   2020-09-02
# 586670  ['4jGPdu95icCKVF31CcFKbS', '5ebPSE9YI5aLeZ1Z2g...   2021-03-05
# 586671                         ['0i4Qda0k4nf7jnNHmSNpYv']   2015-07-01
#
#         danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 0              0.645  0.4450  ...   -13.338     1       0.4510         0.674
# 1              0.695  0.2630  ...   -22.136     1       0.9570         0.797
# 2              0.434  0.1770  ...   -21.180     1       0.0512         0.994
# 3              0.321  0.0946  ...   -27.961     1       0.0504         0.995
# 4              0.402  0.1580  ...   -16.900     0       0.0390         0.989
# ...              ...     ...  ...       ...   ...          ...           ...
# 586667         0.560  0.5180  ...    -7.471     0       0.0292         0.785
# 586668         0.765  0.6630  ...    -5.223     1       0.0652         0.141
# 586669         0.535  0.3140  ...   -12.823     0       0.0408         0.895
# 586670         0.696  0.6150  ...    -6.212     1       0.0345         0.206
# 586671         0.686  0.7230  ...    -7.067     1       0.0363         0.105
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 0               0.744000    0.1510   0.1270  104.851               3
# 1               0.000000    0.1480   0.6550  102.009               1
# 2               0.021800    0.2120   0.4570  130.418               5
# 3               0.918000    0.1040   0.3970  169.980               3
# 4               0.130000    0.3110   0.1960  103.220               4
# ...                  ...       ...      ...      ...             ...
# 586667          0.000000    0.0648   0.2110  131.896               4
# 586668          0.000297    0.0924   0.6860  150.091               4
# 586669          0.000150    0.0874   0.0663  145.095               4
# 586670          0.000003    0.3050   0.4380   90.029               4
# 586671          0.000000    0.2640   0.9750  112.204               4
#
#         Year Released
# 0                1922
# 1                1922
# 2                1922
# 3                1922
# 4                1922
# ...               ...
# 586667           2020
# 586668           2020
# 586669           2020
# 586670           2021
# 586671           2015
#
# [586672 rows x 21 columns]

# %%
#Songs with popularity +80
df_popular = df[df['popularity'] >= 80]
df_popular.dtypes
# Out:
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit              int64
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# Year Released         int64
# dtype: object

# %%
# average danceability for each year || sum(year) / num(year) > year + 1
df_popular.loc[df_popular ['Year Released'] == 1967]
#1967 first year with data for song 80+ popularity
# Out:
#                            id                           name  popularity  \
# 40498  7tqhbajSfrz2F7E1Z75ASX  Ain't No Mountain High Enough          82
# 40499  3yrSvpt2l1xhsV9Em88Pul                Brown Eyed Girl          80
#
#        duration_ms  explicit                           artists  \
# 40498       151667         0  ['Marvin Gaye', 'Tammi Terrell']
# 40499       183307         0                  ['Van Morrison']
#
#                                               id_artists release_date  \
# 40498  ['3koiLjNrgRTNbOwViDipeA', '75jNCko3SnEMI5gwGq...   1967-08-29
# 40499                         ['44NX2ffIYHr6D4n7RaZF7A']      1967-09
#
#        danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 40498         0.663   0.600  ...   -10.870     1       0.0320         0.430
# 40499         0.491   0.583  ...   -10.964     1       0.0376         0.182
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 40498               0.0     0.184    0.800  129.991               4
# 40499               0.0     0.407    0.907  150.572               4
#
#        Year Released
# 40498           1967
# 40499           1967
#
# [2 rows x 21 columns]

# %%
# Avg danceability each year
dance_year = df_popular['danceability'].groupby(df_popular['Year Released'])
print(dance_year.mean())
# Out:
# Year Released
# 1965    0.572000
# 1967    0.577000
# 1969    0.598500
# 1970    0.554000
# 1971    0.414000
# 1972    0.601000
# 1974    0.596000
# 1975    0.414000
# 1976    0.499667
# 1977    0.653400
# 1978    0.663000
# 1979    0.671000
# 1980    0.591667
# 1981    0.500000
# 1982    0.756800
# 1983    0.672000
# 1984    0.566667
# 1985    0.673333
# 1986    0.536500
# 1987    0.566750
# 1990    0.502000
# 1991    0.525167
# 1992    0.565000
# 1993    0.515000
# 1994    0.374500
# 1995    0.647000
# 1996    0.784500
# 1997    0.356000
# 1999    0.680571
# 2000    0.675500
# 2001    0.541200
# 2002    0.665667
# 2003    0.590714
# 2004    0.572000
# 2005    0.634222
# 2006    0.666250
# 2007    0.673000
# 2008    0.661273
# 2009    0.618800
# 2010    0.660867
# 2011    0.652100
# 2012    0.630412
# 2013    0.531278
# 2014    0.627296
# 2015    0.606875
# 2016    0.616914
# 2017    0.655037
# 2018    0.674697
# 2019    0.679372
# 2020    0.716743
# 2021    0.689352
# Name: danceability, dtype: float64

# %%
plt.plot(dance_year.median())

# %% [markdown]
# Next to do: User input chooses the plot with dropdown from tkinter
#             Exclude mode and key

# %%
root = Tk()

root.geometry("200x200")
def show():
    label.config(text=clicked.get())

options = ["duration_ms","explicit","danceability","energy","loudness","speechiness","acousticness","instrumentalness","liveness","valence","tempo","time_signature"]  

clicked = StringVar(root)
clicked.set(options[0])

drop = OptionMenu(root, clicked, *options)
drop.pack()

button = Button(root, text = "Click", command = show).pack()

label = Label(root, text = " ")
label.pack()

root.mainloop()

plot = df_popular[clicked.get()].groupby(df_popular['Year Released'])
plt.plot(plot.mean())

# %% [markdown]
# Need to add correlation/regression? look into stats
# Also add labels
# Note - median may be more useful than mean // could let user choose median or mean

# %%
r = np.corrcoef(df_popular['Year Released'], df_popular['danceability'])
r
# Out:
# array([[1.        , 0.19587456],
#        [0.19587456, 1.        ]])

# %%
df_popular.corr()
#Correlation analysis, numbers close to +/- 1 are strongest corr
# Out:
#                   popularity  duration_ms  explicit  danceability    energy  \
# popularity          1.000000    -0.111639  0.053036      0.066230 -0.064217
# duration_ms        -0.111639     1.000000 -0.099038     -0.204914  0.025430
# explicit            0.053036    -0.099038  1.000000      0.295812 -0.103383
# danceability        0.066230    -0.204914  0.295812      1.000000  0.057289
# energy             -0.064217     0.025430 -0.103383      0.057289  1.000000
# key                -0.010893    -0.010765 -0.004681      0.041932 -0.000204
# loudness           -0.022068    -0.062680 -0.047317      0.162214  0.694491
# mode               -0.019428     0.105380 -0.094389     -0.147060 -0.056962
# speechiness         0.021920    -0.133387  0.366689      0.269486 -0.009082
# acousticness        0.068088    -0.055940 -0.095812     -0.169931 -0.551486
# instrumentalness    0.011512     0.007985 -0.063089     -0.113647 -0.130680
# liveness            0.017114     0.006624  0.026305     -0.097415  0.140808
# valence            -0.012481    -0.043765 -0.082894      0.377844  0.448041
# tempo              -0.026633    -0.000169  0.062020     -0.086459  0.146187
# time_signature     -0.022650     0.006311  0.056583      0.170400  0.182986
# Year Released       0.186430    -0.373750  0.220149      0.195875 -0.117166
#
#                        key  loudness      mode  speechiness  acousticness  \
# popularity       -0.010893 -0.022068 -0.019428     0.021920      0.068088
# duration_ms      -0.010765 -0.062680  0.105380    -0.133387     -0.055940
# explicit         -0.004681 -0.047317 -0.094389     0.366689     -0.095812
# danceability      0.041932  0.162214 -0.147060     0.269486     -0.169931
# energy           -0.000204  0.694491 -0.056962    -0.009082     -0.551486
# key               1.000000  0.010023 -0.114796     0.040117     -0.019266
# loudness          0.010023  1.000000 -0.052011    -0.004762     -0.367263
# mode             -0.114796 -0.052011  1.000000    -0.092617      0.098032
# speechiness       0.040117 -0.004762 -0.092617     1.000000     -0.052978
# acousticness     -0.019266 -0.367263  0.098032    -0.052978      1.000000
# instrumentalness  0.018846 -0.299126  0.009407    -0.013416      0.085062
# liveness          0.018216  0.050627  0.074382    -0.024369     -0.042158
# valence           0.026684  0.340824 -0.015616     0.041174     -0.189817
# tempo            -0.025940  0.137416  0.004056     0.118516     -0.092207
# time_signature   -0.010561  0.224383 -0.040273     0.077905     -0.142626
# Year Released     0.049862  0.150641 -0.110273     0.167713      0.104751
#
#                   instrumentalness  liveness   valence     tempo  \
# popularity                0.011512  0.017114 -0.012481 -0.026633
# duration_ms               0.007985  0.006624 -0.043765 -0.000169
# explicit                 -0.063089  0.026305 -0.082894  0.062020
# danceability             -0.113647 -0.097415  0.377844 -0.086459
# energy                   -0.130680  0.140808  0.448041  0.146187
# key                       0.018846  0.018216  0.026684 -0.025940
# loudness                 -0.299126  0.050627  0.340824  0.137416
# mode                      0.009407  0.074382 -0.015616  0.004056
# speechiness              -0.013416 -0.024369  0.041174  0.118516
# acousticness              0.085062 -0.042158 -0.189817 -0.092207
# instrumentalness          1.000000  0.053112 -0.131596 -0.082890
# liveness                  0.053112  1.000000  0.041331  0.010438
# valence                  -0.131596  0.041331  1.000000  0.033732
# tempo                    -0.082890  0.010438  0.033732  1.000000
# time_signature           -0.235383 -0.000846  0.098930  0.047893
# Year Released            -0.031360 -0.051419 -0.118231  0.004755
#
#                   time_signature  Year Released
# popularity             -0.022650       0.186430
# duration_ms             0.006311      -0.373750
# explicit                0.056583       0.220149
# danceability            0.170400       0.195875
# energy                  0.182986      -0.117166
# key                    -0.010561       0.049862
# loudness                0.224383       0.150641
# mode                   -0.040273      -0.110273
# speechiness             0.077905       0.167713
# acousticness           -0.142626       0.104751
# instrumentalness       -0.235383      -0.031360
# liveness               -0.000846      -0.051419
# valence                 0.098930      -0.118231
# tempo                   0.047893       0.004755
# time_signature          1.000000      -0.021660
# Year Released          -0.021660       1.000000

# %% [markdown]
# Notes for what to explore:
# Find any relationship/intersection between any column against time and popularity against time
# Look into those with interesting Correlations: unstack and sort for those above .3 in either direction, remove duplicates
#
# To do next with that data: data viz

# %%
c = df_popular.corr()

s = c.unstack() #unstack to sort by value
so = s.sort_values(kind="quicksort")
so1 = so[0:8]
result1 = {} # remove duplicates
for key,value in so1.items():
    if value not in result1.values():
        result1[key] = value
result1
# Out:
# {('acousticness', 'energy'): -0.5514855541066971,
#  ('duration_ms', 'Year Released'): -0.3737499334290756,
#  ('loudness', 'acousticness'): -0.3672629443123543,
#  ('loudness', 'instrumentalness'): -0.2991262791539886}

# %%
so2 = so[228:240]

result2 = {}
for key,value in so2.items():
    if value not in result2.values():
        result2[key] = value
result2
# Out:
# {('explicit', 'danceability'): 0.29581155347142707,
#  ('valence', 'loudness'): 0.34082423089895175,
#  ('explicit', 'speechiness'): 0.36668920706218117,
#  ('valence', 'danceability'): 0.3778438874532716,
#  ('energy', 'valence'): 0.44804112253580897,
#  ('loudness', 'energy'): 0.6944910486728548}

# %% [markdown]
# Check if key or mode change correlation

# %%
#dataframe popular - filter by mode 0/1
df_mode_1 = df_popular[df_popular['mode'] == 1]
df_mode_0 = df_popular[df_popular['mode'] == 0]
df_mode_0
# Out:
#                             id                                          name  \
# 48488   4u7EnebtmKWzUH433cf5Qv           Bohemian Rhapsody - Remastered 2011
# 52488   2zYzyRzz6pRmhPzyfMEC8s                               Highway to Hell
# 53489   5vdp5UmvTsnMEMESIF2Ym7  Another One Bites The Dust - Remastered 2011
# 55488   5ChkMS8OtdzJeqyybCc9R5                                   Billie Jean
# 55491   1OOtq8tRnDM8kG2gqUPjAj                                       Beat It
# ...                        ...                                           ...
# 112898  0TDLuuLlV54CkRRUOahJb4                          Titanium (feat. Sia)
# 114192  06KyNuuMOX1ROXRhj787tj    We Don't Talk Anymore (feat. Selena Gomez)
# 115090  26wLOs3ZuHJa2Ihhx6QIE6                                         Teeth
# 156197  161DnLWsx1i3u1JT05lzqU                           Talking to the Moon
# 246629  0BI0hfbmqybnd3TezrDME3      Met Him Last Night (feat. Ariana Grande)
#
#         popularity  duration_ms  explicit                           artists  \
# 48488           83       354320         0                         ['Queen']
# 52488           84       208400         0                         ['AC/DC']
# 53489           83       214653         0                         ['Queen']
# 55488           85       293827         0               ['Michael Jackson']
# 55491           80       258040         0               ['Michael Jackson']
# ...            ...          ...       ...                               ...
# 112898          80       245040         0           ['David Guetta', 'Sia']
# 114192          80       217707         0  ['Charlie Puth', 'Selena Gomez']
# 115090          80       204887         0           ['5 Seconds of Summer']
# 156197          83       217867         0                    ['Bruno Mars']
# 246629          84       204632         1  ['Demi Lovato', 'Ariana Grande']
#
#                                                id_artists release_date  \
# 48488                          ['1dfeR4HaWDbWqFHLkxsg1d']   1975-11-21
# 52488                          ['711MCceyCBcFnzjGY4Q7Un']   1979-07-27
# 53489                          ['1dfeR4HaWDbWqFHLkxsg1d']   1980-06-27
# 55488                          ['3fMbdgg4jU18AjLCKBhRSm']   1982-11-30
# 55491                          ['3fMbdgg4jU18AjLCKBhRSm']   1982-11-30
# ...                                                   ...          ...
# 112898  ['1Cs0zKBU1kc0i8ypK3B9ai', '5WUlDfRSoLAfcVSX1W...   2012-12-07
# 114192  ['6VuMaDnrHyPL1p4EHjYLi7', '0C8ZW7ezQVs4URX5aX...   2016-01-29
# 115090                         ['5Rl15oVamLq7FbSb0NNBNy']   2019-08-23
# 156197                         ['0du5cEVh5yTK9QJze8zA0C']   2010-10-05
# 246629  ['6S2OmqARrzebs0tKUEyXyp', '66CXWjxzNUsdJxJ2Jd...   2021-04-02
#
#         danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 48488          0.414   0.404  ...    -9.928     0       0.0499        0.2710
# 52488          0.574   0.913  ...    -4.793     0       0.1330        0.0610
# 53489          0.933   0.528  ...    -6.472     0       0.1610        0.1120
# 55488          0.920   0.654  ...    -3.051     0       0.0401        0.0236
# 55491          0.779   0.867  ...    -3.704     0       0.0457        0.0491
# ...              ...     ...  ...       ...   ...          ...           ...
# 112898         0.604   0.787  ...    -3.674     0       0.1030        0.0679
# 114192         0.728   0.563  ...    -8.053     0       0.1340        0.6210
# 115090         0.749   0.461  ...    -2.961     0       0.0416        0.0516
# 156197         0.523   0.606  ...    -4.754     0       0.0301        0.5120
# 246629         0.538   0.512  ...    -4.548     0       0.0262        0.2200
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 48488           0.000000    0.3000    0.224   71.105               4
# 52488           0.001580    0.1560    0.423  115.728               4
# 53489           0.312000    0.1630    0.754  109.967               4
# 55488           0.015800    0.0359    0.847  117.046               4
# 55491           0.000008    0.1970    0.915  138.858               4
# ...                  ...       ...      ...      ...             ...
# 112898          0.150000    0.1270    0.301  126.062               4
# 114192          0.000000    0.1790    0.352  100.017               4
# 115090          0.000006    0.0738    0.420  139.020               4
# 156197          0.000000    0.1060    0.065  145.837               4
# 246629          0.000000    0.1010    0.120  144.978               4
#
#         Year Released
# 48488            1975
# 52488            1979
# 53489            1980
# 55488            1982
# 55491            1982
# ...               ...
# 112898           2012
# 114192           2016
# 115090           2019
# 156197           2010
# 246629           2021
#
# [384 rows x 21 columns]

# %%
#mode = 1 correlations -
cm1 = df_mode_1.corr()
cm1 = cm1.drop('mode')
cm1 = cm1.drop('mode', axis = 1) #remove nan

sm1 = cm1.unstack() #unstack to sort by value
som1 = sm1.sort_values(kind="quicksort")
som1 = som1[:]
resultm1 = {} # remove duplicates
for key,value in som1.items():
    if value not in resultm1.values():
        resultm1[key] = value
res = {key : val for key, val in resultm1.items()
                   if type(val) != int and val < -.30}
res
# Out:
# {('energy', 'acousticness'): -0.5989240744230387,
#  ('time_signature', 'instrumentalness'): -0.3988541850619762,
#  ('loudness', 'acousticness'): -0.3748462960644168,
#  ('duration_ms', 'Year Released'): -0.3412253828549607,
#  ('instrumentalness', 'loudness'): -0.3377386241794062}

# %%
#mode = 1 correlations +
sm1_ = cm1.unstack() #unstack to sort by value
som1_ = sm1_.sort_values(kind="quicksort")
som1_ = som1_[:]
resultm1_ = {} # remove duplicates
for key,value in som1_.items():
    if value not in resultm1_.values():
        resultm1_[key] = value
res_ = {key : val for key, val in resultm1_.items()
                   if type(val) != int and val > .30 and val != 1}
res.update(res_)
res
# Out:
# {('energy', 'acousticness'): -0.5989240744230387,
#  ('time_signature', 'instrumentalness'): -0.3988541850619762,
#  ('loudness', 'acousticness'): -0.3748462960644168,
#  ('duration_ms', 'Year Released'): -0.3412253828549607,
#  ('instrumentalness', 'loudness'): -0.3377386241794062,
#  ('valence', 'loudness'): 0.34251089797665984,
#  ('danceability', 'valence'): 0.361656519959746,
#  ('speechiness', 'explicit'): 0.37759384556573417,
#  ('valence', 'energy'): 0.4452559123066824,
#  ('energy', 'loudness'): 0.694245422864013}

# %%
#mode = 0 correlations - 
cm0 = df_mode_0.corr()
cm0 = cm0.drop('mode')
cm0 = cm0.drop('mode', axis = 1) #remove nan

sm0 = cm0.unstack() #unstack to sort by value
som0 = sm0.sort_values(kind="quicksort")
som0 = som0[:]
resultm0 = {} # remove duplicates
for key,value in som0.items():
    if value not in resultm0.values():
        resultm0[key] = value
res0 = {key : val for key, val in resultm0.items()
                   if type(val) != int and val < -.30}
res0
# Out:
# {('energy', 'acousticness'): -0.45180957283487805,
#  ('duration_ms', 'Year Released'): -0.4424409087514309,
#  ('loudness', 'acousticness'): -0.3431927273373411}

# %%
#mode = 0 correlations +
cm0_ = df_mode_0.corr()
cm0_ = cm0_.drop('mode')
cm0_ = cm0_.drop('mode', axis = 1) #remove nan

sm0_ = cm0_.unstack() #unstack to sort by value
som0_ = sm0_.sort_values(kind="quicksort")
som0_ = som0_[:]
resultm0_ = {} # remove duplicates
for key,value in som0_.items():
    if value not in resultm0_.values():
        resultm0_[key] = value
res0_ = {key : val for key, val in resultm0_.items()
                   if type(val) != int and val > .30 and val != 1.0}
res0.update(res0_)
res0
cm0_
# Out:
#                   popularity  duration_ms  explicit  danceability    energy  \
# popularity          1.000000    -0.184527  0.022618      0.057744 -0.094058
# duration_ms        -0.184527     1.000000 -0.119399     -0.187378  0.067546
# explicit            0.022618    -0.119399  1.000000      0.299205 -0.293331
# danceability        0.057744    -0.187378  0.299205      1.000000 -0.002279
# energy             -0.094058     0.067546 -0.293331     -0.002279  1.000000
# key                -0.010291    -0.048384  0.032581      0.115579  0.017265
# loudness           -0.092485     0.000434 -0.204065      0.100436  0.692518
# speechiness        -0.014024    -0.113995  0.340199      0.226480 -0.092066
# acousticness        0.109334    -0.032443  0.000573     -0.135179 -0.451810
# instrumentalness    0.033620    -0.025114 -0.072875     -0.009847 -0.152880
# liveness            0.040185     0.030451  0.041914     -0.080815  0.108857
# valence            -0.028557    -0.003974 -0.098685      0.409293  0.456329
# tempo              -0.017103    -0.082359  0.095909     -0.073524  0.081328
# time_signature     -0.026334    -0.061767 -0.022717      0.046697  0.110746
# Year Released       0.177361    -0.442441  0.220074      0.128609 -0.220349
#
#                        key  loudness  speechiness  acousticness  \
# popularity       -0.010291 -0.092485    -0.014024      0.109334
# duration_ms      -0.048384  0.000434    -0.113995     -0.032443
# explicit          0.032581 -0.204065     0.340199      0.000573
# danceability      0.115579  0.100436     0.226480     -0.135179
# energy            0.017265  0.692518    -0.092066     -0.451810
# key               1.000000  0.013301     0.020381     -0.070167
# loudness          0.013301  1.000000    -0.083914     -0.343193
# speechiness       0.020381 -0.083914     1.000000      0.021312
# acousticness     -0.070167 -0.343193     0.021312      1.000000
# instrumentalness -0.004003 -0.217230     0.037652      0.142593
# liveness         -0.007185  0.019244    -0.044591     -0.023138
# valence           0.063134  0.341474     0.037890     -0.180610
# tempo            -0.007080  0.069568     0.157741      0.000528
# time_signature   -0.058143  0.140640     0.052352     -0.015832
# Year Released     0.113455 -0.088307     0.157230      0.155802
#
#                   instrumentalness  liveness   valence     tempo  \
# popularity                0.033620  0.040185 -0.028557 -0.017103
# duration_ms              -0.025114  0.030451 -0.003974 -0.082359
# explicit                 -0.072875  0.041914 -0.098685  0.095909
# danceability             -0.009847 -0.080815  0.409293 -0.073524
# energy                   -0.152880  0.108857  0.456329  0.081328
# key                      -0.004003 -0.007185  0.063134 -0.007080
# loudness                 -0.217230  0.019244  0.341474  0.069568
# speechiness               0.037652 -0.044591  0.037890  0.157741
# acousticness              0.142593 -0.023138 -0.180610  0.000528
# instrumentalness          1.000000  0.020185 -0.095027 -0.069539
# liveness                  0.020185  1.000000 -0.003354 -0.073048
# valence                  -0.095027 -0.003354  1.000000  0.019492
# tempo                    -0.069539 -0.073048  0.019492  1.000000
# time_signature            0.104607  0.018225  0.029960 -0.012887
# Year Released            -0.036126 -0.070665 -0.120954  0.150071
#
#                   time_signature  Year Released
# popularity             -0.026334       0.177361
# duration_ms            -0.061767      -0.442441
# explicit               -0.022717       0.220074
# danceability            0.046697       0.128609
# energy                  0.110746      -0.220349
# key                    -0.058143       0.113455
# loudness                0.140640      -0.088307
# speechiness             0.052352       0.157230
# acousticness           -0.015832       0.155802
# instrumentalness        0.104607      -0.036126
# liveness                0.018225      -0.070665
# valence                 0.029960      -0.120954
# tempo                  -0.012887       0.150071
# time_signature          1.000000      -0.005259
# Year Released          -0.005259       1.000000

# %% [markdown]
# Use loop to find correlations for all keys

# %%
#d = {}
#for i in range(0,12):
    #d["df_key{0}".format(x)] = df_popular[df_popular['key'] == i]
df_key0 = df_popular[df_popular['key'] == 0]
df_key1 = df_popular[df_popular['key'] == 1]
df_key2 = df_popular[df_popular['key'] == 2]
df_key3 = df_popular[df_popular['key'] == 3]
df_key4 = df_popular[df_popular['key'] == 4]
df_key5 = df_popular[df_popular['key'] == 5]
df_key6 = df_popular[df_popular['key'] == 6]
df_key7 = df_popular[df_popular['key'] == 7]
df_key8 = df_popular[df_popular['key'] == 8]
df_key9 = df_popular[df_popular['key'] == 9]
df_key10 = df_popular[df_popular['key'] == 10]
df_key11 = df_popular[df_popular['key'] == 11]


#Need to automate this process to go through range(0,12)
# Out:
#                             id                                  name  \
# 42488   6dGnYIeXmHdcikdzNNDMm2  Here Comes The Sun - Remastered 2009
# 49489   0GjEhVFGZW8afUYGChu3Rr                         Dancing Queen
# 50490   5e9TFTbltYBg2xThimr0rU             The Chain - 2004 Remaster
# 50491   6A9mKXlFRPMPem6ygQSt7z                    Three Little Birds
# 51489   2grjqo0Frpf2okIBiifQKs                             September
# ...                        ...                                   ...
# 93924   0DlHQxrVijRqVUfuS6PKaY         Deixa de Onda (Porra Nenhuma)
# 93925   0oaY19dUwZimIgzn3ZZLZO                                2 Much
# 94033   3eZYOQO4UzKrUDYDghtnFw                            test drive
# 112649  0qOnSQQF0yzuPWsXrQ9paz     Stereo Hearts (feat. Adam Levine)
# 115460  4umIPjkehX1r7uhmGvXiSV              Intentions (feat. Quavo)
#
#         popularity  duration_ms  explicit  \
# 42488           83       185733         0
# 49489           81       230400         0
# 50490           82       270213         0
# 50491           80       180267         0
# 51489           81       215093         0
# ...            ...          ...       ...
# 93924           83       185000         1
# 93925           82       152796         0
# 94033           80       122174         0
# 112649          84       210960         0
# 115460          81       212867         0
#
#                                     artists  \
# 42488                       ['The Beatles']
# 49489                              ['ABBA']
# 50490                     ['Fleetwood Mac']
# 50491          ['Bob Marley & The Wailers']
# 51489                ['Earth, Wind & Fire']
# ...                                     ...
# 93924        ['DENNIS', 'Xamã', 'LUDMILLA']
# 93925                     ['Justin Bieber']
# 94033                     ['Ariana Grande']
# 112649  ['Gym Class Heroes', 'Adam Levine']
# 115460           ['Justin Bieber', 'Quavo']
#
#                                                id_artists release_date  \
# 42488                          ['3WrFJ7ztbogyGnTHbHJFl2']   1969-09-26
# 49489                          ['0LcJLqbBmaGUft1e9Mm8HV']         1976
# 50490                          ['08GQAI4eElDnROBrJRGE0X']   1977-02-04
# 50491                          ['2QsynagSdAqZj3U9HgDzjD']   1977-01-03
# 51489                          ['4QQgXkCYTt3BlENzhyNETg']   1978-11-23
# ...                                                   ...          ...
# 93924   ['6xlRSRMLgZbsSNd0BMobwy', '5YwzDz4RJfTiMHS4td...   2021-01-21
# 93925                          ['1uNFoZAHBGtllmzznpCI3s']   2021-03-19
# 94033                          ['66CXWjxzNUsdJxJ2JdwvnR']   2021-02-19
# 112649  ['4IJczjB0fJ04gs4uvP0Fli', '4bYPcJP5jwMhSivRcq...   2011-11-11
# 115460  ['1uNFoZAHBGtllmzznpCI3s', '0VRj0yCOv2FXJNP47X...   2020-02-14
#
#         danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 42488          0.557   0.540  ...   -10.484     1       0.0347        0.0339
# 49489          0.543   0.870  ...    -6.514     1       0.0428        0.3580
# 50490          0.545   0.670  ...    -8.810     1       0.0496        0.0090
# 50491          0.814   0.482  ...   -10.493     1       0.0588        0.0111
# 51489          0.697   0.832  ...    -7.264     1       0.0298        0.1680
# ...              ...     ...  ...       ...   ...          ...           ...
# 93924          0.815   0.690  ...    -4.622     1       0.0469        0.2900
# 93925          0.583   0.444  ...    -8.601     1       0.0456        0.5930
# 94033          0.698   0.708  ...    -4.943     0       0.0454        0.0251
# 112649         0.646   0.795  ...    -3.293     1       0.0976        0.0319
# 115460         0.806   0.546  ...    -6.637     1       0.0575        0.3000
#
#         instrumentalness  liveness  valence    tempo  time_signature  \
# 42488           0.002480    0.1790    0.394  129.171               4
# 49489           0.000939    0.7920    0.754  100.804               4
# 50490           0.000822    0.0451    0.481  151.553               4
# 50491           0.000002    0.0476    0.615  148.404               4
# 51489           0.001310    0.2690    0.979  125.926               4
# ...                  ...       ...      ...      ...             ...
# 93924           0.000000    0.3120    0.654  135.036               4
# 93925           0.000000    0.3530    0.167  119.590               4
# 94033           0.000000    0.1240    0.322  115.036               4
# 112649          0.000000    0.2670    0.796   89.990               4
# 115460          0.000000    0.1020    0.874  147.986               4
#
#         Year Released
# 42488            1969
# 49489            1976
# 50490            1977
# 50491            1977
# 51489            1978
# ...               ...
# 93924            2021
# 93925            2021
# 94033            2021
# 112649           2011
# 115460           2020
#
# [68 rows x 21 columns]

# %%
#Correlations for key 0
k0 = df_key0.corr()
k0 = k0.drop('key')
k0 = k0.drop('key', axis = 1) #remove nan

uk0 = k0.unstack() #unstack to sort by value
suk0 = uk0.sort_values(kind="quicksort")
suk0 = suk0[:]
resultk0 = {} # remove duplicates
for key,value in suk0.items():
    if value not in resultk0.values():
        resultk0[key] = value
resk0 = {key : val for key, val in resultk0.items()
                   if type(val) != int and val < -.30}
reskk0_ = {key : val for key, val in resultk0.items()
                   if type(val) != int and val > .30 and val != 1.0}
resk0.update(reskk0_)


#Correlations for key 1
k1 = df_key1.corr()
k1 = k1.drop('key')
k1 = k1.drop('key', axis = 1) #remove nan

uk1 = k1.unstack() #unstack to sort by value
suk1 = uk1.sort_values(kind="quicksort")
suk1 = suk1[:]
resultk1 = {} # remove duplicates
for key,value in suk1.items():
    if value not in resultk1.values():
        resultk1[key] = value
resk1 = {key : val for key, val in resultk1.items()
                   if type(val) != int and val < -.30}
reskk1_ = {key : val for key, val in resultk1.items()
                   if type(val) != int and val > .30 and val != 1.0}
resk1.update(reskk1_)


#Correlations for key 2
k2 = df_key2.corr()
k2 = k2.drop('key')
k2 = k2.drop('key', axis = 1) #remove nan

uk2 = k2.unstack() #unstack to sort by value
suk2 = uk2.sort_values(kind="quicksort")
suk2 = suk2[:]
resultk2 = {} # remove duplicates
for key,value in suk2.items():
    if value not in resultk2.values():
        resultk2[key] = value
resk2 = {key : val for key, val in resultk2.items()
                   if type(val) != int and val < -.30}
reskk2_ = {key : val for key, val in resultk2.items()
                   if type(val) != int and val > .30 and val != 1.0}
resk2.update(reskk2_)

#Correlations for key 3
k3 = df_key3.corr()
k3 = k3.drop('key')
k3 = k3.drop('key', axis = 1) #remove nan

uk3 = k3.unstack() #unstack to sort by value
suk3 = uk3.sort_values(kind="quicksort")
suk3 = suk3[:]
resultk3 = {} # remove duplicates
for key,value in suk3.items():
    if value not in resultk3.values():
        resultk3[key] = value
resk3 = {key : val for key, val in resultk3.items()
                   if type(val) != int and val < -.30}
reskk3_ = {key : val for key, val in resultk3.items()
                   if type(val) != int and val > .30 and val != 1.0}
resk3.update(reskk3_)


#Correlations for key 4
k4 = df_key4.corr()
k4 = k4.drop('key')
k4 = k4.drop('key', axis = 1) #remove nan

uk4 = k4.unstack() #unstack to sort by value
suk4 = uk4.sort_values(kind="quicksort")
suk4 = suk4[:]
resultk4 = {} # remove duplicates
for key,value in suk4.items():
    if value not in resultk4.values():
        resultk4[key] = value
resk4 = {key : val for key, val in resultk4.items()
                   if type(val) != int and val < -.30}
reskk4_ = {key : val for key, val in resultk4.items()
                   if type(val) != int and val > .30 and val != 1.0}
resk4.update(reskk4_)


#Correlations for key 5
k5 = df_key5.corr()
k5 = k5.drop('key')
k5 = k5.drop('key', axis = 1) #remove nan

uk5 = k5.unstack() #unstack to sort by value
suk5 = uk5.sort_values(kind="quicksort")
suk5 = suk5[:]
resultk5 = {} # remove duplicates
for key,value in suk5.items():
    if value not in resultk5.values():
        resultk5[key] = value
resk5 = {key : val for key, val in resultk5.items()
                   if type(val) != int and val < -.30}
reskk5_ = {key : val for key, val in resultk5.items()
                   if type(val) != int and val > .30 and val != 1.0}
resk5.update(reskk5_)


#Correlations for key 6
k6 = df_key6.corr()
k6 = k6.drop('key')
k6 = k6.drop('key', axis = 1) #remove nan

uk6 = k6.unstack() #unstack to sort by value
suk6 = uk6.sort_values(kind="quicksort")
suk6 = suk6[:]
resultk6 = {} # remove duplicates
for key,value in suk6.items():
    if value not in resultk6.values():
        resultk6[key] = value
resk6 = {key : val for key, val in resultk6.items()
                   if type(val) != int and val < -.30}
reskk6_ = {key : val for key, val in resultk6.items()
                   if type(val) != int and val > .30 and val != 1.0}
resk6.update(reskk6_)

#Correlations for key 7
k7 = df_key7.corr()
k7 = k7.drop('key')
k7 = k7.drop('key', axis = 1) #remove nan

uk7 = k7.unstack() #unstack to sort by value
suk7 = uk7.sort_values(kind="quicksort")
suk7 = suk7[:]
resultk7 = {} # remove duplicates
for key,value in suk3.items():
    if value not in resultk7.values():
        resultk7[key] = value
resk7 = {key : val for key, val in resultk7.items()
                   if type(val) != int and val < -.30}
reskk7_ = {key : val for key, val in resultk7.items()
                   if type(val) != int and val > .30 and val != 1.0}
resk7.update(reskk7_)

#Correlations for key 8
k8 = df_key8.corr()
k8 = k8.drop('key')
k8 = k8.drop('key', axis = 1) #remove nan

uk8 = k8.unstack() #unstack to sort by value
suk8 = uk8.sort_values(kind="quicksort")
suk8 = suk8[:]
resultk8 = {} # remove duplicates
for key,value in suk8.items():
    if value not in resultk8.values():
        resultk8[key] = value
resk8 = {key : val for key, val in resultk8.items()
                   if type(val) != int and val < -.30}
reskk8_ = {key : val for key, val in resultk8.items()
                   if type(val) != int and val > .30 and val != 1.0}
resk8.update(reskk8_)

#Correlations for key 9
k9 = df_key9.corr()
k9 = k9.drop('key')
k9 = k9.drop('key', axis = 1) #remove nan

uk9 = k9.unstack() #unstack to sort by value
suk9 = uk9.sort_values(kind="quicksort")
suk9 = suk9[:]
resultk9 = {} # remove duplicates
for key,value in suk9.items():
    if value not in resultk9.values():
        resultk9[key] = value
resk9 = {key : val for key, val in resultk9.items()
                   if type(val) != int and val < -.30}
reskk9_ = {key : val for key, val in resultk9.items()
                   if type(val) != int and val > .30 and val != 1.0}
resk9.update(reskk9_)

#Correlations for key 10
k10 = df_key10.corr()
k10 = k10.drop('key')
k10 = k10.drop('key', axis = 1) #remove nan

uk10 = k10.unstack() #unstack to sort by value
suk10 = uk10.sort_values(kind="quicksort")
suk10 = suk10[:]
resultk10 = {} # remove duplicates
for key,value in suk10.items():
    if value not in resultk10.values():
        resultk10[key] = value
resk10 = {key : val for key, val in resultk10.items()
                   if type(val) != int and val < -.30}
reskk10_ = {key : val for key, val in resultk10.items()
                   if type(val) != int and val > .30 and val != 1.0}
resk10.update(reskk10_)

#Correlations for key 11
k11 = df_key11.corr()
k11 = k11.drop('key')
k11 = k11.drop('key', axis = 1) #remove nan

uk11 = k11.unstack() #unstack to sort by value
suk11 = uk11.sort_values(kind="quicksort")
suk11 = suk11[:]
resultk11 = {} # remove duplicates
for key,value in suk11.items():
    if value not in resultk11.values():
        resultk11[key] = value
resk11 = {key : val for key, val in resultk11.items()
                   if type(val) != int and val < -.30}
reskk11_ = {key : val for key, val in resultk11.items()
                   if type(val) != int and val > .30 and val != 1.0}
resk11.update(reskk11_)

# %%
reskall = {**resk0,**resk1,**resk2,**resk3,**resk4,**resk5,
**resk6,**resk7,**resk8,**resk9,**resk10,**resk11}
reskall = {'col1' : reskall}
dfk = pd.DataFrame(data=reskall)
reskall
# Out:
# {'col1': {('energy', 'acousticness'): -0.6022668488693015,
#   ('loudness', 'acousticness'): -0.39774491287889013,
#   ('Year Released', 'duration_ms'): -0.572380968140356,
#   ('danceability', 'valence'): 0.3255974344424858,
#   ('danceability', 'explicit'): 0.33250870752404116,
#   ('energy', 'valence'): 0.43916970028641705,
#   ('loudness', 'energy'): 0.5865577062743643,
#   ('acousticness', 'energy'): -0.5716659011627306,
#   ('duration_ms', 'Year Released'): -0.46932209295572463,
#   ('valence', 'energy'): 0.34000404815152635,
#   ('explicit', 'speechiness'): 0.46404089804944265,
#   ('valence', 'danceability'): 0.5303167485209495,
#   ('energy', 'loudness'): 0.6537293827264248,
#   ('instrumentalness', 'time_signature'): -0.37378303921573885,
#   ('instrumentalness', 'loudness'): -0.34968439127358464,
#   ('instrumentalness', 'valence'): -0.3706365567165537,
#   ('Year Released', 'loudness'): 0.3125530682119255,
#   ('valence', 'loudness'): 0.31303194017102143,
#   ('danceability', 'mode'): -0.4351228344088007,
#   ('valence', 'mode'): -0.603052191552424,
#   ('valence', 'duration_ms'): -0.5818517640934947,
#   ('speechiness', 'duration_ms'): -0.5124792143350173,
#   ('danceability', 'duration_ms'): -0.44203642255881487,
#   ('duration_ms', 'loudness'): -0.34971912129503746,
#   ('explicit', 'mode'): -0.3481553119113957,
#   ('duration_ms', 'popularity'): -0.323810742936025,
#   ('energy', 'mode'): -0.3143183544393698,
#   ('energy', 'instrumentalness'): -0.45539045647917786,
#   ('explicit', 'instrumentalness'): 0.3178548993821958,
#   ('mode', 'acousticness'): 0.37726286242417645,
#   ('Year Released', 'speechiness'): 0.330800200837599,
#   ('danceability', 'speechiness'): 0.453107559539313,
#   ('popularity', 'explicit'): 0.3474112589437774,
#   ('Year Released', 'popularity'): 0.3785583323391354,
#   ('mode', 'duration_ms'): 0.3959505473734797,
#   ('speechiness', 'popularity'): 0.3999604399825664,
#   ('speechiness', 'explicit'): 0.6291394524659062,
#   ('loudness', 'valence'): 0.30093058785312304,
#   ('acousticness', 'loudness'): -0.4917171575312828,
#   ('duration_ms', 'time_signature'): -0.3740834149084154,
#   ('popularity', 'duration_ms'): -0.35065335911970064,
#   ('acousticness', 'valence'): -0.30972256730574876,
#   ('Year Released', 'acousticness'): 0.3243890943044179,
#   ('mode', 'speechiness'): -0.3639175905520546,
#   ('explicit', 'loudness'): -0.3211682677429788,
#   ('energy', 'explicit'): -0.3015042894940079,
#   ('time_signature', 'danceability'): 0.3441082737912618,
#   ('loudness', 'instrumentalness'): -0.7976517345380939,
#   ('energy', 'Year Released'): -0.3241310242934448,
#   ('duration_ms', 'danceability'): -0.39959129373170554,
#   ('time_signature', 'instrumentalness'): -0.7784638412317076,
#   ('instrumentalness', 'danceability'): -0.4872924476152119,
#   ('tempo', 'instrumentalness'): -0.460716981948693,
#   ('speechiness', 'mode'): -0.40548447277388616,
#   ('instrumentalness', 'duration_ms'): -0.3100223929181654,
#   ('energy', 'tempo'): 0.3059870187786053,
#   ('danceability', 'loudness'): 0.3304611457566733,
#   ('tempo', 'valence'): 0.3348150918949859,
#   ('time_signature', 'energy'): 0.4306068649397647,
#   ('tempo', 'loudness'): 0.4816375376735651,
#   ('danceability', 'time_signature'): 0.605052143600759,
#   ('time_signature', 'loudness'): 0.6395455026088032,
#   ('acousticness', 'time_signature'): -0.3689032691027829,
#   ('loudness', 'time_signature'): 0.32153150145595927,
#   ('danceability', 'acousticness'): -0.38344392706407837,
#   ('energy', 'time_signature'): 0.30616110285613685,
#   ('loudness', 'tempo'): 0.31337811829481016,
#   ('time_signature', 'speechiness'): 0.3167542773292658,
#   ('tempo', 'energy'): 0.3696298652818273,
#   ('speechiness', 'tempo'): 0.4052885453468126,
#   ('speechiness', 'valence'): 0.46723410822698563,
#   ('duration_ms', 'instrumentalness'): 0.5781704566137497}}

# %%
#df_popular.corr().drop_duplicates()
# Out:
# id
# 38498     745H5CctFr12Mo7cqa1BMH
# 40498     7tqhbajSfrz2F7E1Z75ASX
# 40499     3yrSvpt2l1xhsV9Em88Pul
# 42488     6dGnYIeXmHdcikdzNNDMm2
# 42489     4BP3uh0hFLFRb5cjsgLqDh
#                    ...
# 156197    161DnLWsx1i3u1JT05lzqU
# 156198    7BqBn9nzAq8spo5e7cZ0dJ
# 175623    6FE2iI43OZnszFLuLtvvmg
# 178135    6i7zAdNhzUN2k1HcrBxPHG
# 246629    0BI0hfbmqybnd3TezrDME3
# Name: id, Length: 954, dtype: object
#
# name
# 38498                                               My Girl
# 40498                         Ain't No Mountain High Enough
# 40499                                       Brown Eyed Girl
# 42488                  Here Comes The Sun - Remastered 2009
# 42489                                         Fortunate Son
#                                 ...
# 156197                                  Talking to the Moon
# 156198                                 Just the Way You Are
# 175623                                              Classic
# 178135    Head Shoulders Knees & Toes (feat. Norma Jean ...
# 246629             Met Him Last Night (feat. Ariana Grande)
# Name: name, Length: 954, dtype: object
#
# popularity
# 38498     80
# 40498     82
# 40499     80
# 42488     83
# 42489     83
#           ..
# 156197    83
# 156198    83
# 175623    82
# 178135    84
# 246629    84
# Name: popularity, Length: 954, dtype: int64
#
# duration_ms
# 38498     165000
# 40498     151667
# 40499     183307
# 42488     185733
# 42489     140773
#            ...
# 156197    217867
# 156198    220733
# 175623    175427
# 178135    156960
# 246629    204632
# Name: duration_ms, Length: 954, dtype: int64
#
# explicit
# 38498     0
# 40498     0
# 40499     0
# 42488     0
# 42489     0
#          ..
# 156197    0
# 156198    0
# 175623    0
# 178135    0
# 246629    1
# Name: explicit, Length: 954, dtype: int64
#
# artists
# 38498                                   ['The Temptations']
# 40498                      ['Marvin Gaye', 'Tammi Terrell']
# 40499                                      ['Van Morrison']
# 42488                                       ['The Beatles']
# 42489                      ['Creedence Clearwater Revival']
#                                 ...
# 156197                                       ['Bruno Mars']
# 156198                                       ['Bruno Mars']
# 175623                                             ['MKTO']
# 178135    ['Ofenbach', 'Quarterhead', 'Norma Jean Martine']
# 246629                     ['Demi Lovato', 'Ariana Grande']
# Name: artists, Length: 954, dtype: object
#
# id_artists
# 38498                            ['3RwQ26hR2tJtA8F9p2n7jG']
# 40498     ['3koiLjNrgRTNbOwViDipeA', '75jNCko3SnEMI5gwGq...
# 40499                            ['44NX2ffIYHr6D4n7RaZF7A']
# 42488                            ['3WrFJ7ztbogyGnTHbHJFl2']
# 42489                            ['3IYUhFvPQItj6xySrBmZkd']
#                                 ...
# 156197                           ['0du5cEVh5yTK9QJze8zA0C']
# 156198                           ['0du5cEVh5yTK9QJze8zA0C']
# 175623                           ['2l35CQqtYRh3d8ZIiBep4v']
# 178135    ['4AKwRarlmsUlLjIwt38NLw', '2h6hAChW74hB9HvrNo...
# 246629    ['6S2OmqARrzebs0tKUEyXyp', '66CXWjxzNUsdJxJ2Jd...
# Name: id_artists, Length: 954, dtype: object
#
# release_date
# 38498     1965-03-22
# 40498     1967-08-29
# 40499        1967-09
# 42488     1969-09-26
# 42489     1969-11-02
#              ...
# 156197    2010-10-05
# 156198    2010-10-05
# 175623          2012
# 178135    2020-05-08
# 246629    2021-04-02
# Name: release_date, Length: 954, dtype: object
#
# danceability
# 38498     0.572
# 40498     0.663
# 40499     0.491
# 42488     0.557
# 42489     0.640
#           ...
# 156197    0.523
# 156198    0.637
# 175623    0.720
# 178135    0.798
# 246629    0.538
# Name: danceability, Length: 954, dtype: float64
#
# energy
# 38498     0.418
# 40498     0.600
# 40499     0.583
# 42488     0.540
# 42489     0.663
#           ...
# 156197    0.606
# 156198    0.843
# 175623    0.791
# 178135    0.828
# 246629    0.512
# Name: energy, Length: 954, dtype: float64
#
# key
# 38498     0
# 40498     7
# 40499     7
# 42488     9
# 42489     0
#          ..
# 156197    1
# 156198    5
# 175623    1
# 178135    2
# 246629    4
# Name: key, Length: 954, dtype: int64
#
# loudness
# 38498    -10.738
# 40498    -10.870
# 40499    -10.964
# 42488    -10.484
# 42489     -7.516
#            ...
# 156197    -4.754
# 156198    -5.413
# 175623    -4.689
# 178135    -5.360
# 246629    -4.548
# Name: loudness, Length: 954, dtype: float64
#
# mode
# 38498     1
# 40498     1
# 40499     1
# 42488     1
# 42489     1
#          ..
# 156197    0
# 156198    1
# 175623    1
# 178135    1
# 246629    0
# Name: mode, Length: 954, dtype: int64
#
# speechiness
# 38498     0.0349
# 40498     0.0320
# 40499     0.0376
# 42488     0.0347
# 42489     0.0374
#            ...
# 156197    0.0301
# 156198    0.0432
# 175623    0.1240
# 178135    0.1930
# 246629    0.0262
# Name: speechiness, Length: 954, dtype: float64
#
# acousticness
# 38498     0.6350
# 40498     0.4300
# 40499     0.1820
# 42488     0.0339
# 42489     0.2010
#            ...
# 156197    0.5120
# 156198    0.0151
# 175623    0.0384
# 178135    0.0247
# 246629    0.2200
# Name: acousticness, Length: 954, dtype: float64
#
# instrumentalness
# 38498     0.000000
# 40498     0.000000
# 40499     0.000000
# 42488     0.002480
# 42489     0.008060
#             ...
# 156197    0.000000
# 156198    0.000000
# 175623    0.000000
# 178135    0.000003
# 246629    0.000000
# Name: instrumentalness, Length: 954, dtype: float64
#
# liveness
# 38498     0.0961
# 40498     0.1840
# 40499     0.4070
# 42488     0.1790
# 42489     0.1520
#            ...
# 156197    0.1060
# 156198    0.0876
# 175623    0.1570
# 178135    0.1210
# 246629    0.1010
# Name: liveness, Length: 954, dtype: float64
#
# valence
# 38498     0.694
# 40498     0.800
# 40499     0.907
# 42488     0.394
# 42489     0.663
#           ...
# 156197    0.065
# 156198    0.434
# 175623    0.756
# 178135    0.600
# 246629    0.120
# Name: valence, Length: 954, dtype: float64
#
# tempo
# 38498     104.566
# 40498     129.991
# 40499     150.572
# 42488     129.171
# 42489     132.770
#            ...
# 156197    145.837
# 156198    109.012
# 175623    102.071
# 178135    124.962
# 246629    144.978
# Name: tempo, Length: 954, dtype: float64
#
# time_signature
# 38498     4
# 40498     4
# 40499     4
# 42488     4
# 42489     4
#          ..
# 156197    4
# 156198    4
# 175623    4
# 178135    4
# 246629    4
# Name: time_signature, Length: 954, dtype: int64
#
# Year Released
# 38498     1965
# 40498     1967
# 40499     1967
# 42488     1969
# 42489     1969
#           ...
# 156197    2010
# 156198    2010
# 175623    2012
# 178135    2020
# 246629    2021
# Name: Year Released, Length: 954, dtype: int64
