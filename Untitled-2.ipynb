# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
import glob

# %%
path = r'C:\Users\dasan\Desktop\Repo\Project' #Read multiple CSV by pattern matching
all_files = glob.glob(path +"/*.csv")
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
len(df) #Length and types of data in CSV
df.dtypes
# Out:
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit              int64
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# dtype: object

# %%
# x= release date y = average----
df.release_date
# Out:
# 0         1922-02-22
# 1         1922-06-01
# 2         1922-03-21
# 3         1922-03-21
# 4               1922
#              ...
# 586667    2020-09-26
# 586668    2020-10-21
# 586669    2020-09-02
# 586670    2021-03-05
# 586671    2015-07-01
# Name: release_date, Length: 586672, dtype: object

# %% [markdown]
# First exploration -
# 1) filter release_date to only the first 4 characters (year) store as year_released
# 2) filter year_released to popularity > 80
# 2) Find average danceability for each year ex: if release_date == 1990 > mean()
# 3) plot x = year y = avg danceability

# %%
#Year
df["Year Released"] = pd.to_datetime(df['release_date'])
df["Year Released"] = df["Year Released"].dt.year
df
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
#Songs with popularity +80
df_popular = df[df['popularity'] >= 80]
df_popular.dtypes
# Out:
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit              int64
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# Year Released         int64
# dtype: object

# %%
# average danceability for each year || sum(year) / num(year) > year + 1
df_popular.loc[df_popular ['Year Released'] == 1967]
#1967 first year with data for song 80+ popularity
# Out:
#                            id                           name  popularity  \
# 40498  7tqhbajSfrz2F7E1Z75ASX  Ain't No Mountain High Enough          82
# 40499  3yrSvpt2l1xhsV9Em88Pul                Brown Eyed Girl          80
#
#        duration_ms  explicit                           artists  \
# 40498       151667         0  ['Marvin Gaye', 'Tammi Terrell']
# 40499       183307         0                  ['Van Morrison']
#
#                                               id_artists release_date  \
# 40498  ['3koiLjNrgRTNbOwViDipeA', '75jNCko3SnEMI5gwGq...   1967-08-29
# 40499                         ['44NX2ffIYHr6D4n7RaZF7A']      1967-09
#
#        danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 40498         0.663   0.600  ...   -10.870     1       0.0320         0.430
# 40499         0.491   0.583  ...   -10.964     1       0.0376         0.182
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# ...

# %%
 len(df_popular.loc[df_popular['Year Released'] == 1967])
# Out:
# 2

# %%
df1967 = df_popular.loc[df_popular ['Year Released'] == 1969]
df1967['danceability'].mean()
# Out:
# 0.5985

# %%
#alter to one to loop // nan means no songs above 80 that year
i = 1967
x = [1967]
y = []
while i < 2021:
    y.append(df_popular.loc[df_popular['Year Released'] == i, 'danceability'].mean())
    i += 1
    x.append(i)
d = {'Year Released':x,'Danceability':y}
ddf = pd.DataFrame(d, columns =['Year Released','Danceability'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-134-5c1b01a0ba22> in <module>
#       8     x.append(i)
#       9 d = {'Year Released':x,'Danceability':y}
# ---> 10 ddf = pd.DataFrame(d, columns =['Year Released','Danceability'])
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     527
#     528         elif isinstance(data, dict):
# --> 529             mgr = init_dict(data, index, columns, dtype=dtype)
#     530         elif isinstance(data, ma.MaskedArray):
#     531             import numpy.ma.mrecords as mrecords
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\internals\construction.py in init_dict(data, index, columns, dtype)
#     256             # GH10856
#     257             # raise ValueError if only scalars in dict
# ...
