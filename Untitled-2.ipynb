# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 
import numpy as np
import glob

# %%
path = r'C:\Users\dasan\Desktop\Repo\Project' #Read multiple CSV by pattern matching
all_files = glob.glob(path +"/*.csv")
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0)
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)

# %%
len(df) #Length and types of data in CSV
df.dtypes
# Out:
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit              int64
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# dtype: object

# %%
# x= release date y = average----
df.release_date
# Out:
# 0         1922-02-22
# 1         1922-06-01
# 2         1922-03-21
# 3         1922-03-21
# 4               1922
#              ...
# 586667    2020-09-26
# 586668    2020-10-21
# 586669    2020-09-02
# 586670    2021-03-05
# 586671    2015-07-01
# Name: release_date, Length: 586672, dtype: object

# %% [markdown]
# First exploration -
# 1) filter release_date to only the first 4 characters (year) store as year_released
# 2) filter year_released to popularity > 80
# 2) Find average danceability for each year ex: if release_date == 1990 > mean()
# 3) plot x = year y = avg danceability

# %%
#Year
df["Year Released"] = pd.to_datetime(df['release_date'])
df["Year Released"] = df["Year Released"].dt.year
df
# Out:
#                             id                                 name  \
# 0       35iwgR4jXetI318WEWsa1Q                                Carve
# 1       021ht4sdgPcrDgSk7JTbKY  Capítulo 2.16 - Banquero Anarquista
# 2       07A5yehtSnoedViJAZkNnc   Vivo para Quererte - Remasterizado
# 3       08FmqUhxtyLTn6pAh6bk45        El Prisionero - Remasterizado
# 4       08y9GfoqCWfOGsKdwojr5e                  Lady of the Evening
# ...                        ...                                  ...
# 586667  5rgu12WBIHQtvej2MdHSH0                                  云与海
# 586668  0NuWgxEp51CutD2pJoF4OM                                blind
# 586669  27Y1N4Q4U3EfDU5Ubw8ws2            What They'll Say About Us
# 586670  45XJsGpFTyzbzeWK8VzR8S                      A Day At A Time
# 586671  5Ocn6dZ3BJFPWh4ylwFXtn                     Mar de Emociones
#
#         popularity  duration_ms  explicit                          artists  \
# ...

# %%
#Songs with popularity +80
df_popular = df[df['popularity'] >= 80]
df_popular.dtypes
# Out:
# id                   object
# name                 object
# popularity            int64
# duration_ms           int64
# explicit              int64
# artists              object
# id_artists           object
# release_date         object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# time_signature        int64
# Year Released         int64
# dtype: object

# %%
# average danceability for each year || sum(year) / num(year) > year + 1
df_popular.loc[df_popular['Year Released'] == 1965]
# Out:
#                            id     name  popularity  duration_ms  explicit  \
# 38498  745H5CctFr12Mo7cqa1BMH  My Girl          80       165000         0
#
#                    artists                  id_artists release_date  \
# 38498  ['The Temptations']  ['3RwQ26hR2tJtA8F9p2n7jG']   1965-03-22
#
#        danceability  energy  ...  loudness  mode  speechiness  acousticness  \
# 38498         0.572   0.418  ...   -10.738     1       0.0349         0.635
#
#        instrumentalness  liveness  valence    tempo  time_signature  \
# 38498               0.0    0.0961    0.694  104.566               4
#
#        Year Released
# 38498           1965
#
# [1 rows x 21 columns]

# %%
len(df_popular.loc[df_popular['Year Released'] == 1965])
# Out:
# 1
